# %% [markdown]
# <a href="https://colab.research.google.com/github/svetaepc/Python_START/blob/HW_11/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22hw_11__ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

x = symbols('x')
f =  x ** 3 - 50*x
g = -x**4 + 88*x**2 - 241

h = f - g

plot(f, g, (x, -15, 15))

# %%
k = solve(h)
[[el.n().round(2),f.subs(x,el).n().round(2)] for el in k]
# Out:
# [[-9.46, -373.46], [1.42, -68.06], [-1.99, 91.59], [9.03, 284.92]]

# %%
plot(f, g, (x, -12, 12))
